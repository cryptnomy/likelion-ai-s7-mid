# %% [markdown]
# # 가설 1

# %% [markdown]
# ## 라이브러리 임포트

# %%
from glob import glob
import pandas as pd

# %% [markdown]
# ## 데이터 불러오기

# %%
files = sorted(glob('../../../data/likelion-ai-s7-mid/01*/local*.csv'))
files
# Out:
# ['../../../data/likelion-ai-s7-mid\\01_seoul-living-popluation\\LOCAL_PEOPLE_GU_2019.csv',
#  '../../../data/likelion-ai-s7-mid\\01_seoul-living-popluation\\LOCAL_PEOPLE_GU_2020.csv',
#  '../../../data/likelion-ai-s7-mid\\01_seoul-living-popluation\\LOCAL_PEOPLE_GU_2021.csv']

# %%
data = pd.read_csv(files[0], encoding='cp949')
data
# Out:
#           기준일ID  시간대구분        자치구코드      총생활인구수  남자0세부터9세생활인구수  \
# 20190101      0  11110  247783.9476   6613.1044      3564.9470
# 20190101      0  11140  176516.2769   4735.9065      1857.9963
# 20190101      0  11170  287806.8492   7274.7405      3654.3768
# 20190101      0  11200  335106.5204  12278.8839      5306.1528
# 20190101      0  11215  399818.0269  12003.9916      6472.3827
# ...         ...    ...          ...         ...            ...
# 20191231     23  11620  512045.7410  13292.1313      6492.1774
# 20191231     23  11650  507017.9562  17249.4614      9728.3280
# 20191231     23  11680  701730.1925  21768.6379     14313.7773
# 20191231     23  11710  776809.6518  29303.9813     15154.6352
# 20191231     23  11740  522271.9542  20543.7319     10960.7816
#
#           남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# 20190101        6134.7190       12757.6730       13424.9912        9679.4043
# ...
